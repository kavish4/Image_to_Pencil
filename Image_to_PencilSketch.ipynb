# %% [markdown]
# <a href="https://colab.research.google.com/github/kavish4/Image_to_Pencil/blob/main/Image_to_PencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ***Image To Pencil Skectch***

# %% [markdown]
# ### **Kavish Gidwani**

# %% [markdown]
# **LGM Beginner Level Task-4**

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img=cv2.imread('/content/OIP (2).jpg',1)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=268x180 at 0x7FDE473E3C10>

# %% [markdown]
# Converting Image To Gray Scale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=268x180 at 0x7FDE473CA850>

# %% [markdown]
# Inverting Gray Scale Image

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=268x180 at 0x7FDE473EC150>

# %% [markdown]
# Blurring The Image

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

# %%
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=268x180 at 0x7FDE47426F10>

# %% [markdown]
# Converting To Pencil Sketch

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

# %%
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=268x180 at 0x7FDE473EC610>

# %% [markdown]
# ## ***Original Vs Sketch***

# %%
cv2_imshow(img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=RGB size=268x180 at 0x7FDE473E33D0>
# <PIL.Image.Image image mode=L size=268x180 at 0x7FDE473DAB90>

# %%
img2=cv2.imread('/content/OIP.jpg',1)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=197x197 at 0x7FDE473ECFD0>

# %%
img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img2_gray)
# Out:
# <PIL.Image.Image image mode=L size=197x197 at 0x7FDE473DA550>

# %%
img2_invert = cv2.bitwise_not(img2_gray)

# %%
cv2_imshow(img2_invert)
# Out:
# <PIL.Image.Image image mode=L size=197x197 at 0x7FDE473EC8D0>

# %%
img2_smoothing = cv2.GaussianBlur(img2_invert, (21, 21),sigmaX=0, sigmaY=0)

# %%
cv2_imshow(img2_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=197x197 at 0x7FDE473ECFD0>

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img2 = dodgeV2(img2_gray, img2_smoothing)

# %%
cv2_imshow(final_img2)
# Out:
# <PIL.Image.Image image mode=L size=197x197 at 0x7FDE473E34D0>

# %% [markdown]
# ## ***Original Vs Sketch***

# %%
cv2_imshow(img2)
cv2_imshow(final_img2)
# Out:
# <PIL.Image.Image image mode=RGB size=197x197 at 0x7FDE47423310>
# <PIL.Image.Image image mode=L size=197x197 at 0x7FDE473DAE90>
